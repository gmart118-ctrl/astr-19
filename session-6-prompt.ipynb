# %% [markdown]
# # Session 6 Prompt

# %%
import numpy as np
def f(z):
    function = np.sin(x)
    return function

def f(y):
    function = np.cos(x)
    return function

# %% [markdown]
# > The function above defines functions that returns sin(x) and cos(x)

# %%
    x = np.linspace(0,2*np.pi,1000)
    print("x \t\t\tcos(x) \t\t\tsin(x)")
    for i in range(1000):
    	print(f"{x[i]},\t {np.cos(x)[i]},   {np.sin(x)[i]}")
# Out:
# x 			cos(x) 			sin(x)
# 0.0,	 1.0,   0.0
# 0.006289474781961547,	 0.9999802213186832,   0.006289433316067751
# 0.012578949563923095,	 0.9999208860571255,   0.012578617838741058
# 0.018868424345884642,	 0.9998219965624732,   0.01886730478446709
# 0.02515789912784619,	 0.9996835567465339,   0.025155245389375847
# 0.03144737390980774,	 0.9995055720856215,   0.0314421909191206
# 0.037736848691769284,	 0.99928804962034,   0.03772789267871718
# 0.04402632347373083,	 0.9990309979553044,   0.04401210202238166
# 0.05031579825569238,	 0.9987344272588006,   0.05029457036336618
# 0.056605273037653926,	 0.9983983492623831,   0.056575049183792345
# 0.06289474781961547,	 0.9980227772604111,   0.06285329004448194
# 0.06918422260157703,	 0.9976077261095226,   0.06912904459478454
# 0.07547369738353857,	 0.9971532122280464,   0.07540206458240159
# 0.08176317216550011,	 0.9966592535953529,   0.08167210186320663
# 0.08805264694746166,	 0.9961258697511429,   0.08793890841106125
# ...

# %% [markdown]
# > The cell above will tabulate sin(x) and cos(x) using the previously defined functions vs. x, where x is tabulated between 0 and 2 with a thousand entries

# %%
    print("x \t\t\tcos(x) \t\t\tsin(x)")
    for i in range(0,10):
    	print(f"{x[i]},\t {np.cos(x)[i]},   {np.sin(x)[i]}")
# Out:
# x 			cos(x) 			sin(x)
# 0.0,	 1.0,   0.0
# 0.006289474781961547,	 0.9999802213186832,   0.006289433316067751
# 0.012578949563923095,	 0.9999208860571255,   0.012578617838741058
# 0.018868424345884642,	 0.9998219965624732,   0.01886730478446709
# 0.02515789912784619,	 0.9996835567465339,   0.025155245389375847
# 0.03144737390980774,	 0.9995055720856215,   0.0314421909191206
# 0.037736848691769284,	 0.99928804962034,   0.03772789267871718
# 0.04402632347373083,	 0.9990309979553044,   0.04401210202238166
# 0.05031579825569238,	 0.9987344272588006,   0.05029457036336618
# 0.056605273037653926,	 0.9983983492623831,   0.056575049183792345

# %% [markdown]
# > The cell above will use a for loop to print out the first 10 values of x, sin(x), and cos(x) in columns
